# %%
import nfl_data_py as nfl_data

seasons = range(2015, 2025)

# Import necessary data sets for prediction
pbp_downcast_data = nfl_data.import_pbp_data(seasons, downcast=True)
team_data = nfl_data.import_seasonal_data(seasons)
schedules = nfl_data.import_schedules(seasons)
